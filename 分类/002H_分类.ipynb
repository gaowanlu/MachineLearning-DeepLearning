# %%
from sklearn.datasets import fetch_openml
mnist=fetch_openml('mnist_784',version=1)
mnist.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a7b81c13abe1> in <module>
#       1 from sklearn.datasets import fetch_openml
# ----> 2 mnist=fetch_openml('mnist_784',version=1)
#       3 mnist.keys()
#
# D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# D:\anaconda\envs\tensorflow\lib\site-packages\sklearn\datasets\_openml.py in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame)
#     814     # obtain the data
#     815     url = _DATA_FILE.format(data_description['file_id'])
# --> 816     bunch = _download_data_to_bunch(url, return_sparse, data_home,
# ...
